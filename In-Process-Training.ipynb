# %%
# %matplotlib notebook
import tensorwatch as tw

# train = tw.WatcherClient(port=0)
train = tw.WatcherClient()

def show(y,x_name,y_name,event_name,wc=train):
    loss_stream = train.create_stream(expr='lambda d:{}'.format(y), event_name=event_name)
    loss_plot = tw.Visualizer(loss_stream, vis_type='line', xtitle=x_name, ytitle=y_name)
    loss_plot.show()

# %%
# show(x='d.total_t', y='d.tip_target_dis', x_name='time', y_name='tip_target_dis')
# show(x=0, y='d.tip_target_dis', x_name='time', y_name='tip_target_dis')
# show(x='d.tip_target_dis', y='d.tip_target_dis', x_name='time', y_name='tip_target_dis')
show(y='d.tip_target_dis', x_name='time', y_name='tip_target_dis', event_name='tip_target_dis')
# Out:
# <img src="data:image/png;base64,..." width="800">
# ...

# %%
show(y='1/((d.tip_target_dis/1000)**2+1e-8)', x_name='time', y_name='reward', event_name='tip_target_dis')
# Out:
# <img src="data:image/png;base64,..." width="800">
# ...

# %%
show(y='r', x_name='time', y_name='reward', event_name='tip_target_dis')
# Out:
# <img src="data:image/png;base64,..." width="800">
# ...

# %%
show(y='reward', x_name='time', y_name='reward', event_name='reward')
# Out:
# <img src="data:image/png;base64,..." width="800">
# ...

# %%
show(y='d.value_loss', x_name='time', y_name='value_loss', event_name='value_loss')
# Out:
# <img src="data:image/png;base64,..." width="800">
# ...

# %%
show(y='d.loss_policy', x_name='time', y_name='q_value', event_name='loss_policy')
# Out:
# <img src="data:image/png;base64,..." width="800">
# ...

# %%
show(y='d.action', x_name='time', y_name='action', event_name='action')
# Out:
# <img src="data:image/png;base64,..." width="800">
# ...
